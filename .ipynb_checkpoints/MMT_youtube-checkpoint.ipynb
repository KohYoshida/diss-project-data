# %% [markdown]
# ### Collect data from youtube API
# #### tutorial: https://www.youtube.com/watch?v=th5_9woFJmk, official tutorial: https://developers.google.com/youtube/v3/docs?hl=ja, google-api-python-client package: https://github.com/googleapis/google-api-python-client, build() method documentation: https://googleapis.github.io/google-api-python-client/docs/epy/googleapiclient.discovery-module.html#build, instance methods: https://googleapis.github.io/google-api-python-client/docs/dyn/youtube_v3.html, Google Cloud Console: https://console.cloud.google.com/marketplace

# %%
from googleapiclient.discovery import build
import requests
import json
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import json

# %% [markdown]
# #### Topic-ids finder via knowledge graph API (keyword search)

# %%
def search_topicids(query):
    url = "https://kgsearch.googleapis.com/v1/entities:search"
    api_key = 'API key'    
    params = {
        'query': query,
        'limit': 1,
        'indent': True,
        'key': api_key,
    }
    
    response = requests.get(url, params=params)
    data = response.json()
    if 'itemListElement' in data and len(data['itemListElement']) > 0:
        kg_data = data['itemListElement'][0]['result'].get('@id', None)
        if kg_data:
            kg_data = kg_data.replace('kg:', '')
    else:
        kg_data = None
    
    return kg_data

# %% [markdown]
# ### Get more than 50 results at once (You Tube Data API)

# %%
# Define function to search for videos using YouTube API
def search_videos(page_token=None):
    api_key = 'API_KEY'  # Your API key
    youtube = build('youtube', 'v3', developerKey=api_key)
    
    # Set search parameters
    params = {
        'type': 'video',
        'part': 'snippet',
        'maxResults': 50, 
        'regionCode': 'JP',
        'relevanceLanguage': 'ja',
        'order': 'relevance',
        'publishedAfter': '2015-07-01T00:00:00Z',
        'publishedBefore': '2023-07-01T00:00:00Z',
        'q': '"MMT 現代貨幣理論"',
        'pageToken': page_token
    }
    request = youtube.search().list(**params)
    return request.execute()

    # Fetch search results and paginate through them
    results = []
    next_page_token = None
    for _ in range(100):
        response = search_videos(next_page_token)
        results.extend(response['items'])
        next_page_token = response.get('nextPageToken')

        if next_page_token is None:
            break  # Stop if no next page exists

    # Save search results to a JSON file
    with open('search_results.json', 'w') as f:
        json.dump(results, f)

    # Load the saved results from the JSON file
    with open('search_results.json', 'r') as f:
        results = json.load(f)

    # Collect data for each column
    data = []
    for video in results:
        # Extract video details
        video_id = video['id'].get('videoId', None)
        title = video['snippet'].get('title', None)
        description = video['snippet'].get('description', None)
        publish_time = video['snippet'].get('publishedAt', None)
        channel_title = video['snippet'].get('channelTitle', None)
        channel_id = video['snippet'].get('channelId', None)
        etag = video.get('etag', None)
        url = f"https://www.youtube.com/watch?v={video_id}" if video_id else None

        data.append({
            'videoId': video_id,
            'title': title,
            'description': description,
            'publishTime': publish_time,
            'channelTitle': channel_title,
            'channelId': channel_id,
            'etag': etag,
            'url': url
        })

    df = pd.DataFrame(data)

    # Initialize columns to store video details
    df['duration'] = None  # Duration
    df['viewCount'] = None  # View count
    df['likeCount'] = None  # Like count
    df['dislikeCount'] = None  # Dislike count
    df['favoriteCount'] = None  # Favorite count
    df['commentCount'] = None  # Comment count
    df['topicCategory'] = None  # Topic category
    df['topicId'] = None  # Topic ID
    df['videoCategory'] = None  # Video category
    df['videoCategoryId'] = None  # Video category ID

    # Build YouTube API client
    api_key = 'API_KEY'  # Your API key
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Populate the DataFrame with video details
    for index, row in df.iterrows():
        video_id = row['videoId']
        video_response = youtube.videos().list(
            part='contentDetails, statistics, topicDetails, snippet',
            id=video_id
        ).execute()

        # Retrieve the playback duration and add it to the column
        try:
            duration = video_response['items'][0]['contentDetails']['duration']
            df.at[index, 'duration'] = duration
        except KeyError:
            pass

        # Retrieve the view count and add it to the column
        try:
            view_count = video_response['items'][0]['statistics'].get('viewCount', None)
            df.at[index, 'viewCount'] = view_count
        except KeyError:
            pass

        # Retrieve the like count and add it to the column
        try:
            like_count = video_response['items'][0]['statistics'].get('likeCount', None)
            df.at[index, 'likeCount'] = like_count
        except KeyError:
            pass

        # Retrieve the dislike count and add it to the column
        try:
            dislike_count = video_response['items'][0]['statistics'].get('dislikeCount', None)
            df.at[index, 'dislikeCount'] = dislike_count
        except KeyError:
            pass

        # Retrieve the favorite count and add it to the column
        try:
            favorite_count = video_response['items'][0]['statistics'].get('favoriteCount', None)
            df.at[index, 'favoriteCount'] = favorite_count
        except KeyError:
            pass

        # Retrieve the comment count and add it to the column
        try:
            comment_count = video_response['items'][0]['statistics'].get('commentCount', None)
            df.at[index, 'commentCount'] = comment_count
        except KeyError:
            pass

        # Retrieve the topic category and add it to the column
        try:
            topic_categories = video_response['items'][0]['topicDetails'].get('topicCategories', [None])
            topic_categories = [tc.replace('https://en.wikipedia.org/wiki/', '') for tc in topic_categories]
            df.at[index, 'topicCategories'] = topic_categories
        except KeyError:
            pass

        # Retrieve the topic ID and add it to the column
        try:
            topic_ids = [search_topicids(tc) for tc in topic_categories]
            df.at[index, 'topicIds'] = topic_ids
        except KeyError:
            pass

        # Retrieve the video category ID and add it to the column
        try:
            video_category_id = video_response['items'][0]['snippet'].get('categoryId', None)
            df.at[index, 'videoCategoryId'] = video_category_id
        except KeyError:
            pass

        video_category_dict = {
            #... [unchanged dictionary]
        }

        # Retrieve the video category from the corresponding dictionary
        try:
            video_category = video_category_dict.get(video_category_id, None)
            df.at[index, 'videoCategory'] = video_category
        except KeyError:
            pass
    # df = df.replace(r'^\s*$', None, regex=True)
    # df.to_csv('MMT_youtube.csv', index=True)

    # Display the DataFrame
    df
# Out:
#          videoId                                              title  \
# 0    zOe0Go08i90                       【5分で】東大生が教える現代貨幣理論(MMT)入門 前編
# 1    G0KvTvEEQeI                   第17回　国債は無限に出せる？新経済理論ＭＭＴは実は○○○だった
# 2    a4Dhe2jDfq0                    MMT現代貨幣理論入門を20分でざっくりわかりやすく解説する
# 3    K4UHZSPq9h8  【東京ホンマもん教室】間違いだらけの“ＭＭＴ批判”～現代貨幣理論による『正しい』インフレ対策...
# 4    OLE3QMH_EEQ                         【5分で解説！】MMT(現代貨幣理論)とは【経済学】
# ..           ...                                                ...
# 495  Jq_0U72WnjA  【1/2 気持ちいいくらいの完全論破】評論家・中野剛志氏が財政破綻論を完全に論破／立憲・小...
# 4    gBiTI7I8hcQySN7CbGwkZoPGjJs  https://www.youtube.com/watch?v=OLE3QMH_EEQ
# ..                           ...                                          ...
# 495  gjPCK8i9q2TaJBqzLdXmstzKoRQ  https://www.youtube.com/watch?v=Jq_0U72WnjA
# 496  oMNSmJ_VN119BZ2nz_galo0i364  https://www.youtube.com/watch?v=vZoXHOU2DGY
# 497  1PvwK1E2NypNQX5Rm4e6BJItD1s  https://www.youtube.com/watch?v=C12Mllv1nbQ
# 498  dZmYYOGZhZ6LTVuE7tXA2WZ8viA  https://www.youtube.com/watch?v=WQD0ATGMxe8
# 499  CAsa0KLVHlNH4dNuzPmR97EG_s4  https://www.youtube.com/watch?v=r7v5kaev1YQ
#
#      duration viewCount likeCount dislikeCount favoriteCount commentCount  \
# 0     PT4M45S    260441      5804         None             0          980
# 1     PT9M27S    633070     14178         None             0         3401
# 2    PT21M18S     36824       559         None             0          142
# 3    PT55M10S    257713      4242         None             0          672
# 4     PT5M39S     11920       136         None             0           56
# ..        ...       ...       ...          ...           ...          ...
# 495  PT34M21S     23348      1289         None             0          167
# 496    PT4M6S     51107       347         None             0          408
# 497  PT10M55S      8503       202         None             0          284
# 498  PT49M37S       605         5         None             0            0
# 499  PT10M23S    288185      6035         None             0          377
#
#     topicCategory topicId         videoCategory videoCategoryId  \
# 0            None    None             Education              27
# 1            None    None       News & Politics              25
# 2            None    None        People & Blogs              22
# 3            None    None       News & Politics              25
# 4            None    None             Education              27
# ..            ...     ...                   ...             ...
# 495          None    None         Entertainment              24
# 496          None    None       News & Politics              25
# 497          None    None  Science & Technology              28
# 498          None    None                  None              29
# 499          None    None             Education              27
#
#                              topicCategories                    topicIds
# 0                                    Society                    /m/098wr
# 1                                  [Society]                  [/m/098wr]
# 2                                        NaN                  [/m/098wr]
# 3    [Politics, Society, Television_program]  [/m/05qt0, /m/098wr, None]
# 4                                        NaN  [/m/05qt0, /m/098wr, None]
# ..                                       ...                         ...
# 495                                [Society]                  [/m/098wr]
# 496  [Politics, Society, Television_program]  [/m/05qt0, /m/098wr, None]
# 497                                      NaN  [/m/05qt0, /m/098wr, None]
# 498                                [Society]                  [/m/098wr]
# 499                      [Politics, Society]        [/m/05qt0, /m/098wr]
#
# [500 rows x 20 columns]

# %%
# sort by "publish Time"
df['publishTime'] = pd.to_datetime(df['publishTime'])
df = df.sort_values(by='publishTime')
# remove timezone
df['publishTime'] = pd.to_datetime(df['publishTime']).dt.tz_localize(None)
df
# Out:
#          videoId                                              title  \
# 498  WQD0ATGMxe8                第31回京都賞記念講演会　基礎科学部門受賞者：ミシェル・マイヨール博士
# 217  N7NN1zHKIrM      三橋貴明「“国の借金”というウソ！」 政府の負債・日本国債所有者 [モーニングCROSS]
# 409  Zc9-Y5jiIO4        「貨幣と租税」日本の未来を考える勉強会 講師：評論家 中野剛志氏 平成29年4月27日
# 399  Zc9-Y5jiIO4        「貨幣と租税」日本の未来を考える勉強会 講師：評論家 中野剛志氏 平成29年4月27日
# 409  UhRXbk43OmJD7qoza2L6TKHH0XU  https://www.youtube.com/watch?v=Zc9-Y5jiIO4
# 399  UhRXbk43OmJD7qoza2L6TKHH0XU  https://www.youtube.com/watch?v=Zc9-Y5jiIO4
# 488  UEKLs4NtU1lr1BA62t99wSYhqqw  https://www.youtube.com/watch?v=ctTUfLqJf74
# ..                           ...                                          ...
# 423  mK88WzqoY8NQlcRDlMDcUFsrNEw  https://www.youtube.com/watch?v=zvc9iN1nqs4
# 395  RRk_a-D3PHYsjc8DifPFO1DXXHg  https://www.youtube.com/watch?v=8Rsl2s5649Y
# 234  6cSUOMj4166vBzJ3AUTczIBYW5g  https://www.youtube.com/watch?v=VTdSyxHYv5A
# 147  byzloz1SUAG4ltFoUjcFt0xfax8  https://www.youtube.com/watch?v=5shl4izUbrs
# 5    KtdUZRMqB7A-KiKKXiA4MGcIksc  https://www.youtube.com/watch?v=eFtzuZS6ldo
#
#      duration viewCount likeCount dislikeCount favoriteCount commentCount  \
# 498  PT49M37S       605         5         None             0            0
# 217   PT5M31S   1908693     26328         None             0         3889
# 409  PT49M54S     95230      None         None             0          121
# 399  PT49M54S     95230      None         None             0          121
# 488   PT4M17S     62924      None         None             0         None
# ..        ...       ...       ...          ...           ...          ...
# 423   PT15M6S     19351       521         None             0         None
# 395  PT15M38S      9020       606         None             0          154
# 234    PT9M7S      4431       265         None             0           84
# 147      PT1M       217         3         None             0            0
# 5    PT11M55S     17328       557         None             0          287
#
#     topicCategory topicId    videoCategory videoCategoryId  \
# 498          None    None             None              29
# 217          None    None  News & Politics              25
# 409          None    None  News & Politics              25
# 399          None    None  News & Politics              25
# 488          None    None        Education              27
# ..            ...     ...              ...             ...
# 423          None    None    Howto & Style              26
# 395          None    None  News & Politics              25
# 234          None    None  News & Politics              25
# 147          None    None        Education              27
# 5            None    None            Music              10
#
#                      topicCategories              topicIds
# 498                        [Society]            [/m/098wr]
# 217              [Politics, Society]  [/m/05qt0, /m/098wr]
# 409                        [Society]            [/m/098wr]
# 399                        [Society]            [/m/098wr]
# 488  [Health, Lifestyle_(sociology)]      [/m/0kt51, None]
# ..                               ...                   ...
# 423  [Health, Lifestyle_(sociology)]      [/m/0kt51, None]
# 395                        [Society]            [/m/098wr]
# 234                              NaN  [/m/05qt0, /m/098wr]
# 147          [Lifestyle_(sociology)]                [None]
# 5                [Politics, Society]  [/m/05qt0, /m/098wr]
#
# [500 rows x 20 columns]

# %%
# found that videos related to "MMT" is published the most in 2019 in Japan
yearly_counts = df.groupby(df['publishTime'].dt.to_period("Y")).size()
yearly_counts
# Out:
# publishTime
# 2015      1
# 2016      1
# 2017      2
# 2018     18
# 2019    102
# 2020    134
# 2021    112
# 2022     79
# 2023     51
# Freq: A-DEC, dtype: int64

# %%
pip install pandas openpyxl
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ukoda\mmt_youtube\lib\site-packages (from matplotlib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp310-cp310-win_amd64.whl (470 kB)
#      ------------------------------------- 470.4/470.4 kB 14.8 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.0-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\ukoda\mmt_youtube\lib\site-packages (from matplotlib) (1.25.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 13.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ukoda\mmt_youtube\lib\site-packages (from matplotlib) (23.1)
# Collecting pyparsing<3.1,>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ukoda\mmt_youtube\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.0 kiwisolver-1.4.4 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: C:\Users\ukoda\MMT_youtube\Scripts\python.exe -m pip install --upgrade pip

# %%
# keep df as excel file
df.to_excel('MMT-youtube.xlsx', index=False, engine='openpyxl')

# %% [markdown]
# ### Fetch transcription of a video

# %%
video_id = 'eFtzuZS6ldo'  # put the id of the video you want to get the transcription

# Get subtitles via API
transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

# Setup language
transcript = transcript_list.find_generated_transcript(['ja'])

# display all subtitles
for line in transcript.fetch():
    print(line['text'])
# Out:
# ちょっと編集部の方からいただいたテーマ
# の
# 案にとりあえずは
# 従って進めてみるますけれども最初にその
# 全くそのあのこの財政の議論について
# あんまりどんな議論がされてるかっていう
# のをご存じない方もおられるかもしれない
# のでじゃあちょっと最初に
# 緊縮財政論あるいは財政健全化論がその何
# を誤解をしているのか例えば
# 過去最大の
# ウェブサイトでこれが例えば
# 矢野論文矢野さんは相手今の状況日本の
# 状況を例えればタイタニック号が氷山に
# 向かって
# 突進してるようなものだと書いていている
# んですけどもこれは
# 基本的なわかりやすく言うと何を誤解しと
# いうふうに言うと一番直感的にわかり
# やすいですかねまあやはりまずその
# 政府の債務が
# 積み上がると
# まずいとでこれはなんで多くの人がそうだ
# なと思ってしまうかというとおそらくその
# 家系とか企業っていう経済主体と国という
# 経済主体を多分ごっちゃにしちゃってるん
# だと思っていてでこれごっちゃにする理由
# はすごいよくわかるんですよそうですね
# なぜかというと僕ら普通個人として生きて
# ますし普段家系じゃないですか多くの方が
# どっかで働いて給料もらったりするわけな
# のでまあその企業サイドの目線を持ってる
# 方もいれば個人の目線を持つこれは普通だ
# と思うんですよねで国目線って普通持た
# ないと思うんですよ普通の人生送ってたら
# 別に政治家の人なんて限られてるわけです
# しそう考えると多分その無意識のうちに
# 備わってるのって個人と企業の目線である
# とでその目線から見ると
# 借金は悪ですよねと
# でもいいけど
# 返さないってことはありえませんよねって
# いうロジックはすごくわかりやすいって
# いうか確か現実社会においてはそうですよ
# ねとそこに対して国の借金という表現を
# 使って当てはめていけば確かに国の借金が
# 膨れ上がるって事はとてもなんか怖いこと
# のように思えますし
# 返さないと
# 孫とか子供が大変なので苦しいけど
# 税金取られてもしょうがないよねっていう
# ロジックは非常によくできていて確かに
# そのなんか国と個人
# 企業の目線を同じにしてしまうと言ってる
# ことってすごく正しく聞こえちゃうんで
# 国家運営国家財政と
# 企業とかかけて違うでしょっていうところ
# まず分けてないなっていうのが一つとあと
# やっぱりその
# 必ず何かをする時には
# 財源として税収がないといけないという
# 発想ですよねでこれ何でみんなそう思うの
# かなってずっと考えていて逆に言うとどう
# いう説明をすれば分かりやすいのかなって
# いうのを結構考えてたんです本書いたり
# 記事書いたりする際にわかりやすく書か
# ないと読んでもらえないと
# いろいろ考えた時に
# 我々ってもう1000年2000年とか
# こう続いている国のほんと途中で生まれて
# きて多分途中で僕ら死んでいくんだと思う
# んですけどもうすでに1000年とか
# 2000年とか回ってる社会システムの中
# にポコンと生まれて生きているので多分国
# の最初の部分って見てないじゃないですか
# なのであえて今この瞬間自分が王様で国を
# 作りますとで国民がその国はなぜか7人か
# 思いますって最初を考えた時に
# できたばかりの国ですから
# 橋とかも何もないわけでじゃあそこで何か
# 作らなきゃっていう時に国民に作らせよう
# とすると最初にまず金を渡してこれで作れ
# みたい話をしていかなきゃいけないはずで
# 最初の段階でこれから橋作るんで税収必要
# ですと言ってもそもそもお金出回ってない
# んだから何が税収なんだって話になるん
# ですよね国のその
# 成り立ち1日目を考えるとやっぱりどう
# 考えても税収が先に来ないと何もできませ
# んっていう発想はおかしくおかしいですね
# むしろその経済活動していく中で
# 貨幣の流通量が増えていって結果的にその
# 徴収して
# 貨幣をコントロールしていったりとかって
# いう発想での税金なんだよねっていうもの
# が多分やっぱり理解できていないんじゃ
# ないかなとも思いますよねなるほどあれ
# それと同じ議論なんですけど確かに
# そのさっき
# 申し上げたように
# 国が
# 財政破綻しないのは
# その国債を返済すると言っても自国通貨
# 建てで自国通貨は誰が発行してるのか
# ちょっとその国ですと政府ですというよう
# なところは全員が認めているんですね財政
# 再建論者もそうすると今おっしゃってね
# 最初の国の始まりの時最初にお金を出して
# るっていうのと同じなんですけどそれが
# 税収が必要だと税金取らなきゃいけないと
# 財源として税金を取らなきゃいけないと
# いった時に
# 税金って日本の場合何を取ってるんですか
# お金ですと
# 円ですとその円って誰が発行してるんです
# か
# 政府ですと
# なんでじゃあ政府が発行しないと
# 徴収できないですねとそういう順番ですよ
# ねと言うとあれってなるんですけどもそこ
# で
# そうするとじゃあ
# 税金はいらねえじゃねえかとこういう風に
# 巻き込まれていくんですけどね
# 結局そのまあ何でしょうねここもなんか
# 議論がややこしい話で国が金刷れるんだっ
# たら
# 税金なんかいらねえだろうみたいな話当然
# なってくるんですけどただやっぱりもう
# なんかそれをMMT批判にしちゃってる
# 時点でそうなんですよねなんか1丁目1
# 番地の部分をまず無視してお前
# 否定してないかってそうなんですよ話に
# なると思うんですよねでまぁそのこの動画
# 見てる方はねMMTにも
# 賛成だろうが批判的だろうがそれなりに
# 知ってる方が多分興味あって見てると思う
# んで言うまでもないのかもしれないです
# けども
# ま基本的にそもそも
# 租税貨幣論というか
# 税が
# 税を納めるという目的があるからみんな
# そのお金を集めたりとかっていう話が
# そもそも論としてある
# 理論の中でおいて
# 税金いらないっていう批判をしてくるのは
# そもそもMMTそんなこと言ってないし
# みたいな本当にこの批判する態度がなんか
# 言ってもないこと言ったとかそれ冒頭
# 申し上げた話で特にまあ別に
# 普通に働いてる一般の人がなんかおかしい
# と思ってそういう風にじゃあ税金いらなく
# なっちゃうじゃないかっていうぐらいなら
# まだ
# わからないではないんですけど結構立派な
# 大学で教えている教授とかですね
# 政府に影響を与えてる
# 学者とかそういったレベルでもそういう
# ことを言うんですけどもまずその学者とし
# ての訓練として何かを批判するのにそれを
# 全く相手の言ってることを理解しないで
# 批判するっていうのがモラルとしてそんな
# ことやっていいのかなって思うんですが
# これ言うとまた怒られますけど
# 普通はそんなことはおかしいんですけども
# どうもですね主流派の経済学っていうのは
# そういうそういうなんていうか決まりきっ
# たモデルを回してそれに従って回して何か
# その
# 研究した風をしていれば
# 博士が取りになれるとかですね
# 論文になるとかそのモデルの前提を
# 疑うような議論をしないとかですねそう
# いったことがなんかどうも平気で
# まかり通ってる
# らしくて違うんだったらそう言ってくれれ
# ばいいんですけどそう思わざるを得ない
# ぐらいですね
# 全く相手の言ってないことを言ったりとか
# ですねこれ平気でまかり通っていてでそう
# するとこれ怖い話なんですけど一般の人で
# は政治家とか
# 官僚でもいいんですけどもさすがにその
# 東京大学
# 経済学部教授とか一筋橋大学経済学部教授
# とかそういう風な偉い先生が
# 権威を持って
# 言うとやっぱり反論しにくいですねまさか
# そんな相手の
# 言ってることも全くその
# イントロダクションから
# 間違えて
# 批判をしてるあれ読む気もないっていうな
# そういった状態でやってるって普通思わ
# ないじゃないですか
# だからこれがね本当に
# 困っているんですよね大丈夫って本当に
# 思っちゃいますよね
# 冒頭の話と同じなんですけど
# 経済学日本の経済学者は科学者じゃないん
# ですよ事実も見ない
# 論理も
# 矛盾実際すぐ
# 怒鳴るしねすぐ
# 恫喝するし
# 言ってないことを言ったというとかですね
# もうちょっと当たり屋的な感じですね
# 科学的じゃないんですよ全然だからその
# 政府が
# 財政出動ができるとか財政出動したら経済
# がどうのこう成長するとかそのデフレを
# 脱却できるとか
# 根性論じゃなくて別にそういう
# 科学
# なんですけども
# 科学になってなくて結構精神論で
# でも政治家とかでもですねそういうあの
# これびっくりしたんですけどその
# 財政再建論者でも完全にそっち行っちゃっ
# た
# 政治家の先生がですね
# なんか誰に気をつけられたのかドヤ顔で
# その
# 財政出動すればいいって言うけれどもで
# インフレになるまで財政出動すらいいと
# インフレになったら止めればいいと
# 児増税するのに
# 財政抑制するなりすればいいと言うけど
# そんなものはできないと思うんですとか
# 言って言うんですよでもできなくなった国
# って一角もないわけですね当たり前で
# インフレが止まらなくなっても財政出動し
# 続けるような
# 政府は当然支持率が下がって政権選挙で
# 落ちるわけですよだけど政治家がそれを
# です財政民主主義なんだから予算とか税と
# か
# 議会でお決めになることになって民主的な
# コントロール
# 政治家が国会議員が決めることになってる
# わけですよその国会議員が出て止まらなく
# なるんですって言うんだったらお前もう
# やめてくれと政治家なんかなぜやってるん
# だよってじゃあお前どっか行って止め
# られるやつに変えるからどいてくれって話
# なんですよ
# だからみんな勘違いしてんですよ根本的な
# 奇襲と速度を全ての作戦だった中立で
# なければならないって建前になってると
# 主権を尊重してこなかっ
# [音楽]
# だからみんな勘違いしてんですね根本的な
# 奇襲と速度を全ての作戦だった中立で
# なければならないって建前になってると
# 主権を尊重してこなかっ
# [音楽]
# た
# [音楽]
